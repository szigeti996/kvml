# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt

induction = np.array([27, 30, 33.5, 37, 41.5, 44.5, 49, 52, 53,
                      56, 60.5, 61])
induction *= 3.35 # mT

frequency = np.array([3.675, 4.064, 4.515, 5.087, 5.641, 6.167, 6.754, 
                     7.155, 7.285, 7.705, 8.325, 8.496])

plt.plot(induction, frequency, 'ro')

xlabel('Indukció [mT]')
ylabel('Frekvencia [mHz]')

grid(True)

def egyenes(m, x):
    return m*x



plt.savefig('indukció-freki.png')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
current = np.array([0.87, 1.00, 1.15, 1.38, 1.57, 1.74, 1.93, 1.89, 1.94, 2.12,
          2.37, 2.42])

plt.plot(current, induction, 'bo')


xlabel('Áramerősség [A]')
ylabel('Indukció [mT]')

grid(True)

plt.savefig('hiszterezis.png')

# hiszterézis, mert Marci elbaxta
